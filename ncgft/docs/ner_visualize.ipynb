# %%
import spacy
from spacy import displacy
from spacy.tokens import Doc


nlp = spacy.blank('en')

doc = Doc(nlp.vocab,
        words=['Right', '7', 'mm', 'nodule', 'in', 'the', 'right', 'upper', 'lobe', 'noted', 'on', 'CT','.'],
        spaces=[True, True, True, True, True, True, True, True, True, True, True, True, False])

annotations_char_spans = [(0, 5, 'laterality'), (6, 10, 'size'), (11, 17, 'lesion'),(25,41,'location')]

custom_entitites = []
for span_start, span_end, label in annotations_char_spans:
    ent = doc.char_span(span_start, span_end, label=label)
    if ent is None:
        continue
    custom_entitites.append(ent)
doc.ents = custom_entitites

options = {"ents": ['lesion', 'size', 'location', 'laterality'],
           "colors": {'lesion': "#85C1E9", "size": "#FF6961", "location": "#77DD77","laterality":"#F49AC2"}}
displacy.serve(doc, style="ent", host="localhost", port=6060, options=options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#       2 from spacy import displacy
#       3 from spacy.tokens import Doc
#
# File ~/anaconda3/envs/caise-ner/lib/python3.11/site-packages/spacy/__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~/anaconda3/envs/caise-ner/lib/python3.11/site-packages/spacy/errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~/anaconda3/envs/caise-ner/lib/python3.11/site-packages/spacy/compat.py:39
# ...
